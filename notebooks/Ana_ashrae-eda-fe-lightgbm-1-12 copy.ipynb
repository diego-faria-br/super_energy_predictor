# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import gc, math

from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
from sklearn.metrics import mean_squared_error
import lightgbm as lgb
from sklearn.model_selection import KFold, StratifiedKFold, GroupKFold
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ##### Set the size and styles of graphs

# %%
sns.set(rc={'figure.figsize':(11,8)})
sns.set(style="whitegrid")

# %% [markdown]
# ### Read the dataset
# Data is given in different CSV files which we will need to merge afterwards.
#
# `train.csv` only contains the ID of the building and meter related information including our target variable to be predicted (`meter_reading`). This `building_id` is foreign key in `building_metadata.csv`. All the information related to the buildings are given in this file.
#
#
# Same goes for `weather_train.csv` and `building_metadata.csv` files with common column (foreign key) `site_id`. So all three files are related and we will have to join these tables later

# %%
# %%time
metadata_df = pd.read_csv('../raw_data/building_metadata.csv')
train_df = pd.read_csv('../raw_data/train.csv', parse_dates=['timestamp'])
test_df = pd.read_csv('../raw_data/test.csv', parse_dates=['timestamp'])
weather_train_df = pd.read_csv('../raw_data/weather_train.csv', parse_dates=['timestamp'])
weather_test_df = pd.read_csv('../raw_data/weather_test.csv', parse_dates=['timestamp'])
# Out:
# CPU times: user 24.8 s, sys: 5.29 s, total: 30.1 s
# Wall time: 32.5 s

# %%
train_df.head()
# Out:
#    building_id  meter  timestamp  meter_reading
# 0            0      0 2016-01-01            0.0
# 1            1      0 2016-01-01            0.0
# 2            2      0 2016-01-01            0.0
# 3            3      0 2016-01-01            0.0
# 4            4      0 2016-01-01            0.0

# %%
weather_train_df.shape
# Out:
# (139773, 9)

# %%
test_df.head()
# Out:
#    row_id  building_id  meter  timestamp
# 0       0            0      0 2017-01-01
# 1       1            1      0 2017-01-01
# 2       2            2      0 2017-01-01
# 3       3            3      0 2017-01-01
# 4       4            4      0 2017-01-01

# %% [markdown]
# ### Align timestamps
# Timestap data is not in their local time. As energy consumptions are related to the local time, an alighment is nescessary before using timestamp.
#
# The credit goes to [this kernel](https://www.kaggle.com/nz0722/aligned-timestamp-lgbm-by-meter-type) for the idea. Refer it for more details and explanation about below code.

# %%
weather = pd.concat([weather_train_df,weather_test_df],ignore_index=True)
weather_key = ['site_id', 'timestamp']

temp_skeleton = weather[weather_key + ['air_temperature']].drop_duplicates(subset=weather_key).sort_values(by=weather_key).copy()

# calculate ranks of hourly temperatures within date/site_id chunks
temp_skeleton['temp_rank'] = temp_skeleton.groupby(['site_id', temp_skeleton.timestamp.dt.date])['air_temperature'].rank('average')

# create a dataframe of site_ids (0-16) x mean hour rank of temperature within day (0-23)
df_2d = temp_skeleton.groupby(['site_id', temp_skeleton.timestamp.dt.hour])['temp_rank'].mean().unstack(level=1)

# Subtract the columnID of temperature peak by 14, getting the timestamp alignment gap.
site_ids_offsets = pd.Series(df_2d.values.argmax(axis=1) - 14)
site_ids_offsets.index.name = 'site_id'

def timestamp_align(df):
    df['offset'] = df.site_id.map(site_ids_offsets)
    df['timestamp_aligned'] = (df.timestamp - pd.to_timedelta(df.offset, unit='H'))
    df['timestamp'] = df['timestamp_aligned']
    del df['timestamp_aligned']
    return df

# %%
weather_train_df.tail()
# Out:
#         site_id           timestamp  air_temperature  cloud_coverage  \
# 139768       15 2016-12-31 19:00:00              3.0             NaN
# 139769       15 2016-12-31 20:00:00              2.8             2.0
# 139770       15 2016-12-31 21:00:00              2.8             NaN
# 139771       15 2016-12-31 22:00:00              2.2             NaN
# 139772       15 2016-12-31 23:00:00              1.7             NaN
#
#         dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# 139768             -8.0                NaN                 NaN
# 139769             -8.9                NaN              1007.4
# 139770             -7.2                NaN              1007.5
# 139771             -6.7                NaN              1008.0
# 139772             -5.6               -1.0              1008.5
#
#         wind_direction  wind_speed
# 139768           180.0         5.7
# 139769           180.0         7.7
# 139770           180.0         5.1
# 139771           170.0         4.6
# 139772           180.0         8.8

# %%
weather_train_df = timestamp_align(weather_train_df)
weather_test_df = timestamp_align(weather_test_df)

# %%
del weather 
del df_2d
del temp_skeleton
del site_ids_offsets

# %%
weather_train_df.tail()
# Out:
#         site_id           timestamp  air_temperature  cloud_coverage  \
# 139768       15 2016-12-31 13:00:00              3.0             NaN
# 139769       15 2016-12-31 14:00:00              2.8             2.0
# 139770       15 2016-12-31 15:00:00              2.8             NaN
# 139771       15 2016-12-31 16:00:00              2.2             NaN
# 139772       15 2016-12-31 17:00:00              1.7             NaN
#
#         dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# 139768             -8.0                NaN                 NaN
# 139769             -8.9                NaN              1007.4
# 139770             -7.2                NaN              1007.5
# 139771             -6.7                NaN              1008.0
# 139772             -5.6               -1.0              1008.5
#
#         wind_direction  wind_speed  offset
# 139768           180.0         5.7       6
# 139769           180.0         7.7       6
# 139770           180.0         5.1       6
# 139771           170.0         4.6       6
# 139772           180.0         8.8       6

# %% [markdown]
# ### Fill NaNs in weather data by interpolation

# %%
weather_train_df.isna().sum()
# Out:
# site_id                   0
# timestamp                 0
# air_temperature          55
# cloud_coverage        69173
# dew_temperature         113
# precip_depth_1_hr     50289
# sea_level_pressure    10618
# wind_direction         6268
# wind_speed              304
# offset                    0
# dtype: int64

# %%
weather_train_df.columns
# Out:
# Index(['site_id', 'timestamp', 'air_temperature', 'cloud_coverage',
#        'dew_temperature', 'precip_depth_1_hr', 'sea_level_pressure',
#        'wind_direction', 'wind_speed', 'offset'],
#       dtype='object')

# %%
weather_test_df.isna().sum()
# Out:
# site_id                    0
# timestamp                  0
# air_temperature          104
# cloud_coverage        140448
# dew_temperature          327
# precip_depth_1_hr      95588
# sea_level_pressure     21265
# wind_direction         12370
# wind_speed               460
# offset                     0
# dtype: int64

# %%
weather_train_df['air_temperature'] = weather_train_df[['site_id','air_temperature' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

weather_train_df['cloud_coverage'] = weather_train_df[['site_id','cloud_coverage' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

weather_train_df['dew_temperature' ] = weather_train_df[['site_id','dew_temperature' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

weather_train_df['precip_depth_1_hr'] = weather_train_df[['site_id','precip_depth_1_hr' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

weather_train_df['sea_level_pressure'] = weather_train_df[['site_id','sea_level_pressure' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

weather_train_df['wind_direction'] = weather_train_df[['site_id','wind_direction' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

weather_train_df['wind_speed' ] = weather_train_df[['site_id','wind_speed' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# Out:
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/1377668585.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_train_df['air_temperature'] = weather_train_df[['site_id','air_temperature' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/1377668585.py:3: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_train_df['cloud_coverage'] = weather_train_df[['site_id','cloud_coverage' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/1377668585.py:5: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_train_df['dew_temperature' ] = weather_train_df[['site_id','dew_temperature' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/1377668585.py:7: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_train_df['precip_depth_1_hr'] = weather_train_df[['site_id','precip_depth_1_hr' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/1377668585.py:9: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_train_df['sea_level_pressure'] = weather_train_df[['site_id','sea_level_pressure' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/1377668585.py:11: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_train_df['wind_direction'] = weather_train_df[['site_id','wind_direction' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/1377668585.py:13: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_train_df['wind_speed' ] = weather_train_df[['site_id','wind_speed' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

# %%
weather_test_df['air_temperature'] = weather_test_df[['site_id','air_temperature' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

weather_test_df['cloud_coverage']=weather_test_df[['site_id','cloud_coverage' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

weather_test_df['dew_temperature' ]=weather_test_df[['site_id','dew_temperature' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

weather_test_df['precip_depth_1_hr']=weather_test_df[['site_id','precip_depth_1_hr' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

weather_test_df['sea_level_pressure']=weather_test_df[['site_id','sea_level_pressure' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

weather_test_df['wind_direction']=weather_test_df[['site_id','wind_direction' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

weather_test_df['wind_speed' ]=weather_test_df[['site_id','wind_speed' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# Out:
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/2820823235.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_test_df['air_temperature'] = weather_test_df[['site_id','air_temperature' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/2820823235.py:3: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_test_df['cloud_coverage']=weather_test_df[['site_id','cloud_coverage' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/2820823235.py:5: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_test_df['dew_temperature' ]=weather_test_df[['site_id','dew_temperature' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/2820823235.py:7: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_test_df['precip_depth_1_hr']=weather_test_df[['site_id','precip_depth_1_hr' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/2820823235.py:9: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_test_df['sea_level_pressure']=weather_test_df[['site_id','sea_level_pressure' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/2820823235.py:11: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_test_df['wind_direction']=weather_test_df[['site_id','wind_direction' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]
# /var/folders/jn/fmk11xqs3fqg4zt98nw043b80000gn/T/ipykernel_18514/2820823235.py:13: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather_test_df['wind_speed' ]=weather_test_df[['site_id','wind_speed' ]].groupby('site_id').apply(lambda group: group.interpolate(limit_direction='both')).iloc[:,1]

# %%
weather_train_df.isna().sum()
# Out:
# site_id                   0
# timestamp                 0
# air_temperature           0
# cloud_coverage        17228
# dew_temperature           0
# precip_depth_1_hr     26273
# sea_level_pressure     8755
# wind_direction            0
# wind_speed                0
# offset                    0
# dtype: int64

# %%
weather_test_df.isna().sum()
# Out:
# site_id                   0
# timestamp                 0
# air_temperature           0
# cloud_coverage        33146
# dew_temperature           0
# precip_depth_1_hr     51807
# sea_level_pressure    17241
# wind_direction            0
# wind_speed                0
# offset                    0
# dtype: int64

# %%
train_df['meter_reading'] = np.log1p(train_df['meter_reading'])

# %%
weather_train_df.head()
# Out:
#    site_id           timestamp  air_temperature  cloud_coverage  \
# 0        0 2015-12-31 19:00:00             25.0             6.0
# 1        0 2015-12-31 20:00:00             24.4             4.0
# 2        0 2015-12-31 21:00:00             22.8             2.0
# 3        0 2015-12-31 22:00:00             21.1             2.0
# 4        0 2015-12-31 23:00:00             20.0             2.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0             20.0               -1.0              1019.7             0.0
# 1             21.1               -1.0              1020.2            70.0
# 2             21.1                0.0              1020.2             0.0
# 3             20.6                0.0              1020.1             0.0
# 4             20.0               -1.0              1020.0           250.0
#
#    wind_speed  offset
# 0         0.0       5
# 1         1.5       5
# 2         0.0       5
# 3         0.0       5
# 4         2.6       5

# %%
## Function to reduce the memory usage
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
le = LabelEncoder()
metadata_df['primary_use'] = le.fit_transform(metadata_df['primary_use'])

# %%
metadata_df = reduce_mem_usage(metadata_df)
train_df = reduce_mem_usage(train_df)
test_df = reduce_mem_usage(test_df)
weather_train_df = reduce_mem_usage(weather_train_df)
weather_test_df = reduce_mem_usage(weather_test_df)
# Out:
# Mem. usage decreased to  0.02 Mb (74.9% reduction)
# Mem. usage decreased to 250.63 Mb (59.4% reduction)
# Mem. usage decreased to 596.49 Mb (53.1% reduction)
# Mem. usage decreased to  3.20 Mb (70.0% reduction)
# Mem. usage decreased to  6.35 Mb (70.0% reduction)

# %% [markdown]
# #### Get insights of shapes and first few data rows of all the files

# %%
print (f'Training data shape: {train_df.shape}')
print (f'Weather training shape: {weather_train_df.shape}')
print (f'Weather training shape: {weather_test_df.shape}')
print (f'Weather testing shape: {metadata_df.shape}')
print (f'Test data shape: {test_df.shape}')
# Out:
# Training data shape: (20216100, 4)
# Weather training shape: (139773, 10)
# Weather training shape: (277243, 10)
# Weather testing shape: (1449, 6)
# Test data shape: (41697600, 4)

# %%
train_df.head()
# Out:
#    building_id  meter  timestamp  meter_reading
# 0            0      0 2016-01-01            0.0
# 1            1      0 2016-01-01            0.0
# 2            2      0 2016-01-01            0.0
# 3            3      0 2016-01-01            0.0
# 4            4      0 2016-01-01            0.0

# %%
weather_train_df.head()
# Out:
#    site_id           timestamp  air_temperature  cloud_coverage  \
# 0        0 2015-12-31 19:00:00        25.000000             6.0
# 1        0 2015-12-31 20:00:00        24.406250             4.0
# 2        0 2015-12-31 21:00:00        22.796875             2.0
# 3        0 2015-12-31 22:00:00        21.093750             2.0
# 4        0 2015-12-31 23:00:00        20.000000             2.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0         20.00000               -1.0              1019.5             0.0
# 1         21.09375               -1.0              1020.0            70.0
# 2         21.09375                0.0              1020.0             0.0
# 3         20.59375                0.0              1020.0             0.0
# 4         20.00000               -1.0              1020.0           250.0
#
#    wind_speed  offset
# 0    0.000000       5
# 1    1.500000       5
# 2    0.000000       5
# 3    0.000000       5
# 4    2.599609       5

# %%
metadata_df.head()
# Out:
#    site_id  building_id  primary_use  square_feet  year_built  floor_count
# 0        0            0            0         7432      2008.0          NaN
# 1        0            1            0         2720      2004.0          NaN
# 2        0            2            0         5376      1991.0          NaN
# 3        0            3            0        23685      2002.0          NaN
# 4        0            4            0       116607      1975.0          NaN

# %%
test_df.head()
# Out:
#    row_id  building_id  meter  timestamp
# 0       0            0      0 2017-01-01
# 1       1            1      0 2017-01-01
# 2       2            2      0 2017-01-01
# 3       3            3      0 2017-01-01
# 4       4            4      0 2017-01-01

# %% [markdown]
# #### Merge necessary files
# As mentioned previously, to get a single dataframe for training and a single data frame for testing with all the feature included, we need to join the tables/files which are related by foreign keys. Let's first merge/join training data.

# %%
train_df.head()
# Out:
#    building_id  meter  timestamp  meter_reading
# 0            0      0 2016-01-01            0.0
# 1            1      0 2016-01-01            0.0
# 2            2      0 2016-01-01            0.0
# 3            3      0 2016-01-01            0.0
# 4            4      0 2016-01-01            0.0

# %%
# %%time
full_train_df = train_df.merge(metadata_df, on='building_id', how='left')
full_train_df = full_train_df.merge(weather_train_df, on=['site_id', 'timestamp'], how='left')
# Out:
# CPU times: user 6.75 s, sys: 3.16 s, total: 9.91 s
# Wall time: 11.3 s

# %% [markdown]
# Drop all NaN rows which are generated by timestamp alignment

# %%
full_train_df = full_train_df.loc[~(full_train_df['air_temperature'].isnull() & full_train_df['cloud_coverage'].isnull() & full_train_df['dew_temperature'].isnull() & full_train_df['precip_depth_1_hr'].isnull() & full_train_df['sea_level_pressure'].isnull() & full_train_df['wind_direction'].isnull() & full_train_df['wind_speed'].isnull() & full_train_df['offset'].isnull())]

# %%
full_train_df.shape
# Out:
# (20112649, 17)

# %% [markdown]
# #### Reducing the memory usage
# Let's delete unnecessary dataframes from memory to lower the memory usage

# %%
# Delete unnecessary dataframes to decrease memory usage
del train_df
del weather_train_df
gc.collect()
# Out:
# 187

# %% [markdown]
# Now let's change the data types of necessary feature columns based on the range of the data values. This will lower the data usage. But **how**? Let's see. For example the datatype of feature `building_id` is `int64` but based on the range of this feature, it can be accomodated in lower range i.e. `int16`. So this will decrease the memory usage.

# %% [markdown]
# #### Let's do the same for test data

# %%
# %%time
full_test_df = test_df.merge(metadata_df, on='building_id', how='left')
full_test_df = full_test_df.merge(weather_test_df, on=['site_id', 'timestamp'], how='left')
# Out:
# CPU times: user 14.4 s, sys: 9.56 s, total: 24 s
# Wall time: 29.8 s

# %%
full_test_df.shape
# Out:
# (41697600, 17)

# %% [markdown]
# #### Reducing the memory usage
# Let's delete unnecessary dataframes from memory to lower the memory usage

# %%
# Delete unnecessary dataframes to decrease memory usage
del metadata_df
del weather_test_df
del test_df
gc.collect()
# Out:
# 0

# %% [markdown]
# Now let's change the data types of necessary feature columns based on the range of the data values. This will lower the data usage. But **how**? Let's see. For example the datatype of feature `building_id` is `int64` but based on the range of this feature, it can be accomodated in lower range i.e. `int16`. So this will decrease the memory usage.

# %%
full_train_df.head()
# Out:
#    building_id  meter  timestamp  meter_reading  site_id  primary_use  \
# 0            0      0 2016-01-01            0.0        0            0
# 1            1      0 2016-01-01            0.0        0            0
# 2            2      0 2016-01-01            0.0        0            0
# 3            3      0 2016-01-01            0.0        0            0
# 4            4      0 2016-01-01            0.0        0            0
#
#    square_feet  year_built  floor_count  air_temperature  cloud_coverage  \
# 0         7432      2008.0          NaN         19.40625             4.0
# 1         2720      2004.0          NaN         19.40625             4.0
# 2         5376      1991.0          NaN         19.40625             4.0
# 3        23685      2002.0          NaN         19.40625             4.0
# 4       116607      1975.0          NaN         19.40625             4.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0         19.40625                0.0              1019.5             0.0
# 1         19.40625                0.0              1019.5             0.0
# 2         19.40625                0.0              1019.5             0.0
# 3         19.40625                0.0              1019.5             0.0
# 4         19.40625                0.0              1019.5             0.0
#
#    wind_speed  offset
# 0         0.0     5.0
# 1         0.0     5.0
# 2         0.0     5.0
# 3         0.0     5.0
# 4         0.0     5.0

# %% [markdown]
# ### Distribition of primary usage of buildings

# %%
ax = sns.barplot(le.inverse_transform(full_train_df.groupby(['primary_use']).size().reset_index(name='counts')['primary_use']), full_train_df.groupby(['primary_use']).size().reset_index(name='counts')['counts'])
ax.set(xlabel='Primary Usage', ylabel='# of records', title='Primary Usage vs. # of records')
ax.set_xticklabels(ax.get_xticklabels(), rotation=50, ha="right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [40], line 1
# ----> 1 ax = sns.barplot(le.inverse_transform(full_train_df.groupby(['primary_use']).size().reset_index(name='counts')['primary_use']), full_train_df.groupby(['primary_use']).size().reset_index(name='counts')['counts'])
#       2 ax.set(xlabel='Primary Usage', ylabel='# of records', title='Primary Usage vs. # of records')
#       3 ax.set_xticklabels(ax.get_xticklabels(), rotation=50, ha="right")
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# ### Distribution of meter types

# %%
meter_types = {0: 'electricity', 1: 'chilledwater', 2: 'steam', 3: 'hotwater'}
ax = sns.barplot(np.vectorize(meter_types.get)(pd.unique(full_train_df['meter'])), full_train_df['meter'].value_counts())
ax.set(xlabel='Meter Type', ylabel='# of records', title='Meter type vs. # of records')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [41], line 2
#       1 meter_types = {0: 'electricity', 1: 'chilledwater', 2: 'steam', 3: 'hotwater'}
# ----> 2 ax = sns.barplot(np.vectorize(meter_types.get)(pd.unique(full_train_df['meter'])), full_train_df['meter'].value_counts())
#       3 ax.set(xlabel='Meter Type', ylabel='# of records', title='Meter type vs. # of records')
#       4 plt.show()
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# ### Average meter reading for training dataset

# %%
# Average meter reading
print (f'Average meter reading: {full_train_df.meter_reading.mean()} kWh')
# Out:
# Average meter reading: nan kWh

# %% [markdown]
# ### Distribution of meter readings for each meter type

# %%
ax = sns.barplot(np.vectorize(meter_types.get)(full_train_df.groupby(['meter'])['meter_reading'].mean().keys()), full_train_df.groupby(['meter'])['meter_reading'].mean())
ax.set(xlabel='Meter Type', ylabel='Meter reading', title='Meter type vs. Meter Reading')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [43], line 1
# ----> 1 ax = sns.barplot(np.vectorize(meter_types.get)(full_train_df.groupby(['meter'])['meter_reading'].mean().keys()), full_train_df.groupby(['meter'])['meter_reading'].mean())
#       2 ax.set(xlabel='Meter Type', ylabel='Meter reading', title='Meter type vs. Meter Reading')
#       3 plt.show()
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# ### Distribution of buildings built in each year for both training and test datasets

# %%
fig, ax = plt.subplots(1,1,figsize=(14, 6))
ax.set(xlabel='Year Built', ylabel='# Of Buildings', title='Buildings built in each year')
full_train_df['year_built'].value_counts(dropna=False).sort_index().plot(ax=ax)
full_test_df['year_built'].value_counts(dropna=False).sort_index().plot(ax=ax)
ax.legend(['Train', 'Test']);

# %% [markdown]
# ### Distribution of square feet area of buildings

# %%
fig, ax = plt.subplots(1,1,figsize=(15, 7))
full_train_df.groupby(['building_id'])['square_feet'].mean().plot(ax=ax)
ax.set(xlabel='Building ID', ylabel='Area in Square Feet', title='Square Feet area of buildings')
plt.show()

# %% [markdown]
# ## Feature Engineering
# The joined dataframe (full_train_df) now has 20,216,100 rows, and 16 features in training dataset.

# %% [markdown]
# ### Analysing missing data
# First let's count and fill missing data in training datasets

# %%
pd.DataFrame(full_train_df.isna().sum().sort_values(ascending=False), columns=['NaN Count'])
# Out:
#                     NaN Count
# floor_count          16618674
# year_built           12105206
# precip_depth_1_hr     1646098
# sea_level_pressure     779195
# cloud_coverage         476553
# air_temperature             0
# wind_speed                  0
# wind_direction              0
# dew_temperature             0
# building_id                 0
# meter                       0
# square_feet                 0
# primary_use                 0
# site_id                     0
# meter_reading               0
# timestamp                   0
# offset                      0

# %% [markdown]
# Missing data can be filled in many ways. Here are few techniques to fill missing values:
#
# * Ignore the data row
# * Back-fill or forward-fill to propagate next or previous values respectively
# * Replace with some constant value outside fixed value range-999,-1 etc.
# * Replace with mean, median value
#
# For now, we will go with last method. So let's fill all the missing data with it's average(mean) values of corresponding columns.

# %%
def mean_without_overflow_fast(col):
    col /= len(col)
    return col.mean() * len(col)

# %%
missing_values = (100-full_train_df.count() / len(full_train_df) * 100).sort_values(ascending=False)

# %%
# %%time
missing_features = full_train_df.loc[:, missing_values > 0.0]
missing_features = missing_features.apply(mean_without_overflow_fast)
# Out:
# CPU times: user 1.25 s, sys: 769 ms, total: 2.02 s
# Wall time: 2.24 s

# %%
for key in full_train_df.loc[:, missing_values > 0.0].keys():
    if key == 'year_built' or key == 'floor_count':
        full_train_df[key].fillna(math.floor(missing_features[key]), inplace=True)
        full_test_df[key].fillna(math.floor(missing_features[key]), inplace=True)
    else:
        full_train_df[key].fillna(missing_features[key], inplace=True)
        full_test_df[key].fillna(missing_features[key], inplace=True)

# %%
full_train_df.tail()
# Out:
#           building_id  meter           timestamp  meter_reading  site_id  \
# 20215251         1064      0 2016-12-31 23:00:00       5.042969       12
# 20215252         1065      0 2016-12-31 23:00:00       1.827148       12
# 20215253         1066      0 2016-12-31 23:00:00       3.291016       12
# 20215254         1067      0 2016-12-31 23:00:00       5.445312       12
# 20215255         1068      0 2016-12-31 23:00:00       4.050781       12
#
#           primary_use  square_feet  year_built  floor_count  air_temperature  \
# 20215251            0       131212      1968.0          4.0              6.5
# 20215252            6        12152      1968.0          4.0              6.5
# 20215253            0        55800      1968.0          4.0              6.5
# 20215254            0       125701      1968.0          4.0              6.5
# 20215255            0       112956      1968.0          4.0              6.5
#
#           cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 20215251             8.0         5.300781            1.25556
# 20215252             8.0         5.300781            1.25556
# 20215253             8.0         5.300781            1.25556
# 20215254             8.0         5.300781            1.25556
# 20215255             8.0         5.300781            1.25556
#
#           sea_level_pressure  wind_direction  wind_speed  offset
# 20215251              1019.5           340.0         6.0     0.0
# 20215252              1019.5           340.0         6.0     0.0
# 20215253              1019.5           340.0         6.0     0.0
# 20215254              1019.5           340.0         6.0     0.0
# 20215255              1019.5           340.0         6.0     0.0

# %%
full_test_df.tail()
# Out:
#             row_id  building_id  meter           timestamp  site_id  \
# 41697595  41697595         1444      0 2018-05-09 07:00:00       15
# 41697596  41697596         1445      0 2018-05-09 07:00:00       15
# 41697597  41697597         1446      0 2018-05-09 07:00:00       15
# 41697598  41697598         1447      0 2018-05-09 07:00:00       15
# 41697599  41697599         1448      0 2018-05-09 07:00:00       15
#
#           primary_use  square_feet  year_built  floor_count  air_temperature  \
# 41697595            1        19619      1914.0          4.0         18.90625
# 41697596            0         4298      1968.0          4.0         18.90625
# 41697597            1        11265      1997.0          4.0         18.90625
# 41697598            4        29775      2001.0          4.0         18.90625
# 41697599            6        92271      2001.0          4.0         18.90625
#
#           cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 41697595             0.0        10.601562               -1.0
# 41697596             0.0        10.601562               -1.0
# 41697597             0.0        10.601562               -1.0
# 41697598             0.0        10.601562               -1.0
# 41697599             0.0        10.601562               -1.0
#
#           sea_level_pressure  wind_direction  wind_speed  offset
# 41697595              1020.5           180.0    2.599609     6.0
# 41697596              1020.5           180.0    2.599609     6.0
# 41697597              1020.5           180.0    2.599609     6.0
# 41697598              1020.5           180.0    2.599609     6.0
# 41697599              1020.5           180.0    2.599609     6.0

# %% [markdown]
# So all the missing values for training and testing data is now filled with the mean of corresponding feature columns.

# %% [markdown]
# ### Adding few more features

# %% [markdown]
# First let's expand timestamp to multiple components

# %%
full_train_df['timestamp'].dtype
# Out:
# dtype('<M8[ns]')

# %%
full_train_df["timestamp"] = pd.to_datetime(full_train_df["timestamp"])
full_test_df["timestamp"] = pd.to_datetime(full_test_df["timestamp"])

# %%
def transform(df):
    df['hour'] = np.uint8(df['timestamp'].dt.hour)
    df['day'] = np.uint8(df['timestamp'].dt.day)
    df['weekday'] = np.uint8(df['timestamp'].dt.weekday)
    df['month'] = np.uint8(df['timestamp'].dt.month)
    df['year'] = np.uint8(df['timestamp'].dt.year-1900)
    
    df['square_feet'] = np.log(df['square_feet'])
    
    return df

# %%
full_train_df = transform(full_train_df)
full_test_df = transform(full_test_df)

# %%
def encode_cyclic_feature(df, col, max_vals):
    df[col + '_sin'] = np.sin(2 * np.pi * df[col]/max_vals)
#     df[col + '_cos'] = np.cos(2 * np.pi * df[col]/max_vals)
    del df[col]
    return df

# %%
full_train_df.head()
# Out:
#    building_id  meter  timestamp  meter_reading  site_id  primary_use  \
# 0            0      0 2016-01-01            0.0        0            0
# 1            1      0 2016-01-01            0.0        0            0
# 2            2      0 2016-01-01            0.0        0            0
# 3            3      0 2016-01-01            0.0        0            0
# 4            4      0 2016-01-01            0.0        0            0
#
#    square_feet  year_built  floor_count  air_temperature  ...  \
# 0     8.913550      2008.0          4.0         19.40625  ...
# 1     7.908387      2004.0          4.0         19.40625  ...
# 2     8.589700      1991.0          4.0         19.40625  ...
# 3    10.072597      2002.0          4.0         19.40625  ...
# 4    11.666565      1975.0          4.0         19.40625  ...
#
#    precip_depth_1_hr  sea_level_pressure  wind_direction  wind_speed  offset  \
# 0                0.0              1019.5             0.0         0.0     5.0
# 1                0.0              1019.5             0.0         0.0     5.0
# 2                0.0              1019.5             0.0         0.0     5.0
# 3                0.0              1019.5             0.0         0.0     5.0
# 4                0.0              1019.5             0.0         0.0     5.0
#
#    hour  day  weekday  month  year
# 0     0    1        4      1   116
# 1     0    1        4      1   116
# 2     0    1        4      1   116
# 3     0    1        4      1   116
# 4     0    1        4      1   116
#
# [5 rows x 22 columns]

# %%
dates_range = pd.date_range(start='2015-12-31', end='2019-01-01')
us_holidays = calendar().holidays(start=dates_range.min(), end=dates_range.max())
full_train_df['is_holiday'] = (full_train_df['timestamp'].dt.date.astype('datetime64').isin(us_holidays)).astype(np.int8)
full_test_df['is_holiday'] = (full_test_df['timestamp'].dt.date.astype('datetime64').isin(us_holidays)).astype(np.int8)

# %%
# Assuming 5 days a week for all the given buildings
full_train_df.loc[(full_train_df['weekday'] == 5) | (full_train_df['weekday'] == 6) , 'is_holiday'] = 1
full_test_df.loc[(full_test_df['weekday']) == 5 | (full_test_df['weekday'] == 6) , 'is_holiday'] = 1

# %%
# full_train_df.loc[(full_train_df['primary_use'] == le.transform(['Education'])[0]) & (full_train_df['month'] >= 6) & (full_train_df['month'] <= 8), 'is_vacation_month'] = np.int8(1)
# full_train_df.loc[full_train_df['is_vacation_month']!=1, 'is_vacation_month'] = np.int8(0)

# %% [markdown]
# ### Removing weired data on site_id 0
# As you can see above, this data looks weired until May 20. It is reported in this discussion by @barnwellguy that All electricity meter is 0 until May 20 for site_id == 0. Let's remove these data from training data.

# %%
full_train_df.shape
# Out:
# (20112649, 23)

# %%
full_train_df = full_train_df.query('not (building_id <= 104 & meter == 0 & timestamp <= "2016-05-20")')

# %%
full_train_df.shape
# Out:
# (19766435, 23)

# %%
full_test_df = full_test_df.drop(['timestamp'], axis=1)
full_train_df = full_train_df.drop(['timestamp'], axis=1)
print (f'Shape of training dataset: {full_train_df.shape}')
print (f'Shape of testing dataset: {full_test_df.shape}')
# Out:
# Shape of training dataset: (19766435, 22)
# Shape of testing dataset: (41697600, 22)

# %%
full_train_df.tail()
# Out:
#           building_id  meter  meter_reading  site_id  primary_use  \
# 20215251         1064      0       5.042969       12            0
# 20215252         1065      0       1.827148       12            6
# 20215253         1066      0       3.291016       12            0
# 20215254         1067      0       5.445312       12            0
# 20215255         1068      0       4.050781       12            0
#
#           square_feet  year_built  floor_count  air_temperature  \
# 20215251    11.784570      1968.0          4.0              6.5
# 20215252     9.405249      1968.0          4.0              6.5
# 20215253    10.929529      1968.0          4.0              6.5
# 20215254    11.741661      1968.0          4.0              6.5
# 20215255    11.634754      1968.0          4.0              6.5
#
#           cloud_coverage  ...  sea_level_pressure  wind_direction  wind_speed  \
# 20215251             8.0  ...              1019.5           340.0         6.0
# 20215252             8.0  ...              1019.5           340.0         6.0
# 20215253             8.0  ...              1019.5           340.0         6.0
# 20215254             8.0  ...              1019.5           340.0         6.0
# 20215255             8.0  ...              1019.5           340.0         6.0
#
#           offset  hour  day  weekday  month  year  is_holiday
# 20215251     0.0    23   31        5     12   116           1
# 20215252     0.0    23   31        5     12   116           1
# 20215253     0.0    23   31        5     12   116           1
# 20215254     0.0    23   31        5     12   116           1
# 20215255     0.0    23   31        5     12   116           1
#
# [5 rows x 22 columns]

# %%
full_train_df.tail()
# Out:
#           building_id  meter  meter_reading  site_id  primary_use  \
# 20215251         1064      0       5.042969       12            0
# 20215252         1065      0       1.827148       12            6
# 20215253         1066      0       3.291016       12            0
# 20215254         1067      0       5.445312       12            0
# 20215255         1068      0       4.050781       12            0
#
#           square_feet  year_built  floor_count  air_temperature  \
# 20215251    11.784570      1968.0          4.0              6.5
# 20215252     9.405249      1968.0          4.0              6.5
# 20215253    10.929529      1968.0          4.0              6.5
# 20215254    11.741661      1968.0          4.0              6.5
# 20215255    11.634754      1968.0          4.0              6.5
#
#           cloud_coverage  ...  sea_level_pressure  wind_direction  wind_speed  \
# 20215251             8.0  ...              1019.5           340.0         6.0
# 20215252             8.0  ...              1019.5           340.0         6.0
# 20215253             8.0  ...              1019.5           340.0         6.0
# 20215254             8.0  ...              1019.5           340.0         6.0
# 20215255             8.0  ...              1019.5           340.0         6.0
#
#           offset  hour  day  weekday  month  year  is_holiday
# 20215251     0.0    23   31        5     12   116           1
# 20215252     0.0    23   31        5     12   116           1
# 20215253     0.0    23   31        5     12   116           1
# 20215254     0.0    23   31        5     12   116           1
# 20215255     0.0    23   31        5     12   116           1
#
# [5 rows x 22 columns]

# %%
## Reducing memory
full_train_df = reduce_mem_usage(full_train_df)
full_test_df = reduce_mem_usage(full_test_df)
gc.collect()
# Out:
# Mem. usage decreased to 810.58 Mb (41.1% reduction)
# Mem. usage decreased to 1789.47 Mb (40.0% reduction)
# 3775

# %%
beaufort = [(0, 0, 0.3), (1, 0.3, 1.6), (2, 1.6, 3.4), (3, 3.4, 5.5), (4, 5.5, 8), (5, 8, 10.8), (6, 10.8, 13.9), 
          (7, 13.9, 17.2), (8, 17.2, 20.8), (9, 20.8, 24.5), (10, 24.5, 28.5), (11, 28.5, 33), (12, 33, 200)]

for item in beaufort:
    full_train_df.loc[(full_train_df['wind_speed']>=item[1]) & (full_train_df['wind_speed']<item[2]), 'beaufort_scale'] = item[0]

# %%
full_train_df['group'] = full_train_df['month']
full_train_df['group'].replace((1,2,3,4,5,6), 1,inplace=True)
full_train_df['group'].replace((7,8,9,10,11,12), 2, inplace=True)

# %%
full_train_df = encode_cyclic_feature(full_train_df, 'weekday', 7)
full_train_df = encode_cyclic_feature(full_train_df, 'hour', 24)
full_train_df = encode_cyclic_feature(full_train_df, 'day', 31)
full_train_df = encode_cyclic_feature(full_train_df, 'month', 12)

# %%
full_train_df = reduce_mem_usage(full_train_df)
# Out:
# Mem. usage decreased to 904.84 Mb (33.3% reduction)

# %%
categoricals = ['site_id', 'building_id', 'primary_use', 'meter',  'wind_direction', 'is_holiday']
drop_cols = ['sea_level_pressure', 'wind_speed']
numericals = ['square_feet', 'year_built', 'air_temperature', 'cloud_coverage',
              'dew_temperature', 'precip_depth_1_hr', 'floor_count', 'beaufort_scale', 'weekday_sin', 'day_sin', 'hour_sin', 'month_sin']

feat_cols = categoricals + numericals

# %%
full_train_df.tail()
# Out:
#           building_id  meter  meter_reading  site_id  primary_use  \
# 20215251         1064      0       5.042969       12            0
# 20215252         1065      0       1.827148       12            6
# 20215253         1066      0       3.291016       12            0
# 20215254         1067      0       5.445312       12            0
# 20215255         1068      0       4.050781       12            0
#
#           square_feet  year_built  floor_count  air_temperature  \
# 20215251    11.781250      1968.0          4.0              6.5
# 20215252     9.406250      1968.0          4.0              6.5
# 20215253    10.929688      1968.0          4.0              6.5
# 20215254    11.742188      1968.0          4.0              6.5
# 20215255    11.632812      1968.0          4.0              6.5
#
#           cloud_coverage  ...  wind_direction  wind_speed  offset  year  \
# 20215251             8.0  ...           340.0         6.0     0.0   116
# 20215252             8.0  ...           340.0         6.0     0.0   116
# 20215253             8.0  ...           340.0         6.0     0.0   116
# 20215254             8.0  ...           340.0         6.0     0.0   116
# 20215255             8.0  ...           340.0         6.0     0.0   116
#
#           is_holiday  group  weekday_sin  hour_sin  day_sin  month_sin
# 20215251           1      2    -0.975098 -0.258789     -0.0       -0.0
# 20215252           1      2    -0.975098 -0.258789     -0.0       -0.0
# 20215253           1      2    -0.975098 -0.258789     -0.0       -0.0
# 20215254           1      2    -0.975098 -0.258789     -0.0       -0.0
# 20215255           1      2    -0.975098 -0.258789     -0.0       -0.0
#
# [5 rows x 23 columns]

# %%
full_train_df = reduce_mem_usage(full_train_df)
gc.collect()
# Out:
# Mem. usage decreased to 904.84 Mb (0.0% reduction)
# 0

# %%
target = full_train_df["meter_reading"]
del full_train_df["meter_reading"]

# %%
full_train_df.drop(drop_cols, axis=1)
gc.collect()
# Out:
# 0

# %%
# Save the testing dataset to freeup the RAM. We'll read after training
# full_test_df.to_pickle('full_test_df.pkl')
# del full_test_df
# gc.collect()

# %%
full_train_df.head()
# Out:
#      building_id  meter  site_id  primary_use  square_feet  year_built  \
# 103          105      0        1            0    10.835938      1968.0
# 104          106      0        1            0     8.585938      1968.0
# 105          106      3        1            0     8.585938      1968.0
# 106          107      0        1            0    11.484375      2005.0
# 107          108      0        1            0    11.312500      1913.0
#
#      floor_count  air_temperature  cloud_coverage  dew_temperature  ...  \
# 103          5.0         3.800781             0.0         2.400391  ...
# 104          4.0         3.800781             0.0         2.400391  ...
# 105          4.0         3.800781             0.0         2.400391  ...
# 106         10.0         3.800781             0.0         2.400391  ...
# 107          5.0         3.800781             0.0         2.400391  ...
#
#      wind_direction  wind_speed  offset  year  is_holiday  group  weekday_sin  \
# 103           240.0    3.099609     0.0   116           1      1    -0.433838
# 104           240.0    3.099609     0.0   116           1      1    -0.433838
# 105           240.0    3.099609     0.0   116           1      1    -0.433838
# 106           240.0    3.099609     0.0   116           1      1    -0.433838
# 107           240.0    3.099609     0.0   116           1      1    -0.433838
#
#      hour_sin   day_sin  month_sin
# 103       0.0  0.201294        0.5
# 104       0.0  0.201294        0.5
# 105       0.0  0.201294        0.5
# 106       0.0  0.201294        0.5
# 107       0.0  0.201294        0.5
#
# [5 rows x 22 columns]

# %%
params = {
            'boosting_type': 'gbdt',
            'objective': 'regression',
            'metric': {'rmse'},
            'subsample': 0.4,
            'subsample_freq': 1,
            'learning_rate': 0.25,
            'num_leaves': 31,
            'feature_fraction': 0.8,
            'lambda_l1': 1,
            'lambda_l2': 1
            }

folds = 2
seed = 666

# kf = StratifiedKFold(n_splits=folds, shuffle=False, random_state=seed)

# models = []
# for train_index, val_index in kf.split(full_train_df, full_train_df['building_id']):
#     train_X = full_train_df[feat_cols].iloc[train_index]
#     val_X = full_train_df[feat_cols].iloc[val_index]
#     train_y = target.iloc[train_index]
#     val_y = target.iloc[val_index]
#     lgb_train = lgb.Dataset(train_X, train_y, categorical_feature=categoricals)
#     lgb_eval = lgb.Dataset(val_X, val_y, categorical_feature=categoricals)
#     gbm = lgb.train(params,
#                 lgb_train,
#                 num_boost_round=500,
#                 valid_sets=(lgb_train, lgb_eval),
#                 early_stopping_rounds=100,
#                 verbose_eval = 100)
#     models.append(gbm)
kf = GroupKFold(n_splits=folds)

models = []
for train_index, val_index in kf.split(full_train_df, full_train_df['building_id'], groups=full_train_df['group']):
#     train_X, train_y = full_train_df[feat_cols].loc[train_index], full_train_df['meter_reading'][train_index]
#     val_X, val_y = full_train_df[feat_cols].loc[val_index], full_train_df['meter_reading'][val_index]
    train_X = full_train_df[feat_cols].iloc[train_index]
    val_X = full_train_df[feat_cols].iloc[val_index]
    train_y = target.iloc[train_index]
    val_y = target.iloc[val_index]
    lgb_train = lgb.Dataset(train_X, train_y, categorical_feature=categoricals)
    lgb_eval = lgb.Dataset(val_X, val_y, categorical_feature=categoricals)
    gbm = lgb.train(params,
                lgb_train,
                num_boost_round=500,
                valid_sets=(lgb_train, lgb_eval),
                early_stopping_rounds=100,
                verbose_eval = 100)
    models.append(gbm)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [79], line 40
#      36 models = []
#      37 for train_index, val_index in kf.split(full_train_df, full_train_df['building_id'], groups=full_train_df['group']):
#      38 #     train_X, train_y = full_train_df[feat_cols].loc[train_index], full_train_df['meter_reading'][train_index]
#      39 #     val_X, val_y = full_train_df[feat_cols].loc[val_index], full_train_df['meter_reading'][val_index]
# ---> 40     train_X = full_train_df[feat_cols].iloc[train_index]
#      41     val_X = full_train_df[feat_cols].iloc[val_index]
#      42     train_y = target.iloc[train_index]
#
# File ~/.pyenv/versions/3.8.12/envs/sep/lib/python3.8/site-packages/pandas/core/frame.py:3810, in DataFrame.__getitem__(self, key)
#    3808     if is_iterator(key):
#    3809         key = list(key)
# -> 3810     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3812 # take() does not accept boolean indexers
#    3813 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/3.8.12/envs/sep/lib/python3.8/site-packages/pandas/core/indexes/base.py:6111, in Index._get_indexer_strict(self, key, axis_name)
#    6108 else:
#    6109     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6111 self._raise_if_missing(keyarr, indexer, axis_name)
#    6113 keyarr = self.take(indexer)
#    6114 if isinstance(key, Index):
#    6115     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/3.8.12/envs/sep/lib/python3.8/site-packages/pandas/core/indexes/base.py:6174, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6171     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6173 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6174 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['beaufort_scale'] not in index"

# %%
del full_train_df, train_X, val_X, lgb_train, lgb_eval, train_y, val_y, target
gc.collect()
# Out:
# 207

# %%
# full_test_df = pd.read_pickle('full_test_df.pkl')

# %%
# full_test_df.loc[(full_test_df['primary_use'] == le.transform(['Education'])[0]) & (full_test_df['month'] >= 6) & (full_test_df['month'] <= 8), 'is_vacation_month'] = np.int8(1)
# full_test_df.loc[full_test_df['is_vacation_month']!=1, 'is_vacation_month'] = np.int8(0)

# %%
for item in beaufort:
    full_test_df.loc[(full_test_df['wind_speed']>=item[1]) & (full_test_df['wind_speed']<item[2]), 'beaufort_scale'] = item[0]

# %%
full_test_df = encode_cyclic_feature(full_test_df, 'weekday', 7)
full_test_df = encode_cyclic_feature(full_test_df, 'hour', 24)
full_test_df = encode_cyclic_feature(full_test_df, 'day', 31)
full_test_df = encode_cyclic_feature(full_test_df, 'month', 12)

# %%
full_test_df = full_test_df[feat_cols]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [81], line 1
# ----> 1 full_test_df = full_test_df[feat_cols]
#
# File ~/.pyenv/versions/3.8.12/envs/sep/lib/python3.8/site-packages/pandas/core/frame.py:3810, in DataFrame.__getitem__(self, key)
#    3808     if is_iterator(key):
#    3809         key = list(key)
# -> 3810     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3812 # take() does not accept boolean indexers
#    3813 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/3.8.12/envs/sep/lib/python3.8/site-packages/pandas/core/indexes/base.py:6111, in Index._get_indexer_strict(self, key, axis_name)
#    6108 else:
#    6109     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6111 self._raise_if_missing(keyarr, indexer, axis_name)
#    6113 keyarr = self.take(indexer)
#    6114 if isinstance(key, Index):
#    6115     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/3.8.12/envs/sep/lib/python3.8/site-packages/pandas/core/indexes/base.py:6174, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6171     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6173 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6174 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['beaufort_scale'] not in index"

# %%
full_test_df = reduce_mem_usage(full_test_df)
# Out:
# Mem. usage decreased to 1590.64 Mb (42.9% reduction)

# %%
i=0
res=[]
step_size = 50000
for j in tqdm(range(int(np.ceil(full_test_df.shape[0]/50000)))):
    res.append(np.expm1(sum([model.predict(full_test_df.iloc[i:i+step_size]) for model in models])/folds))
    i+=step_size
# Out:
# 100%|█████████████████████████████████████████| 834/834 [01:41<00:00,  8.23it/s]

# %%
res = np.concatenate(res)
res
# Out:
# array([4.47213582, 3.98585156, 2.52212927, ..., 0.70260194, 5.0991021 ,
#        1.39273501])

# %%
full_test_df
# Out:
#           site_id  building_id  primary_use  meter  wind_direction  \
# 0               0            0            0      0           130.0
# 1               0            1            0      0           130.0
# 2               0            2            0      0           130.0
# 3               0            3            0      0           130.0
# 4               0            4            0      0           130.0
# ...           ...          ...          ...    ...             ...
# 41697595       15         1444            1      0           180.0
# 41697596       15         1445            0      0           180.0
# 41697597       15         1446            1      0           180.0
# 41697598       15         1447            4      0           180.0
# 41697599       15         1448            6      0           180.0
#
#           is_holiday  square_feet  year_built  air_temperature  \
# 0                  0     8.914062      2008.0        15.601562
# 1                  0     7.910156      2004.0        15.601562
# 2                  0     8.585938      1991.0        15.601562
# 3                  0    10.070312      2002.0        15.601562
# 4                  0    11.664062      1975.0        15.601562
# ...              ...          ...         ...              ...
# 41697595           0     9.882812      1914.0        18.906250
# 41697596           0     8.367188         NaN        18.906250
# 41697597           0     9.328125      1997.0        18.906250
# 41697598           0    10.304688      2001.0        18.906250
# 41697599           0    11.429688      2001.0        18.906250
#
#           cloud_coverage  dew_temperature  precip_depth_1_hr  floor_count  \
# 0                    2.0        12.796875                0.0          NaN
# 1                    2.0        12.796875                0.0          NaN
# 2                    2.0        12.796875                0.0          NaN
# 3                    2.0        12.796875                0.0          NaN
# 4                    2.0        12.796875                0.0          NaN
# ...                  ...              ...                ...          ...
# 41697595             0.0        10.601562               -1.0          NaN
# 41697596             0.0        10.601562               -1.0          NaN
# 41697597             0.0        10.601562               -1.0          NaN
# 41697598             0.0        10.601562               -1.0          NaN
# 41697599             0.0        10.601562               -1.0          NaN
#
#           beaufort_scale  weekday_sin   day_sin  hour_sin  month_sin
# 0                    2.0    -0.781738  0.201294   0.00000        0.5
# 1                    2.0    -0.781738  0.201294   0.00000        0.5
# 2                    2.0    -0.781738  0.201294   0.00000        0.5
# 3                    2.0    -0.781738  0.201294   0.00000        0.5
# 4                    2.0    -0.781738  0.201294   0.00000        0.5
# ...                  ...          ...       ...       ...        ...
# 41697595             2.0     0.975098  0.968262   0.96582        0.5
# 41697596             2.0     0.975098  0.968262   0.96582        0.5
# 41697597             2.0     0.975098  0.968262   0.96582        0.5
# 41697598             2.0     0.975098  0.968262   0.96582        0.5
# 41697599             2.0     0.975098  0.968262   0.96582        0.5
#
# [41697600 rows x 18 columns]

# %%
submission = pd.read_csv('/kaggle/input/ashrae-energy-prediction/sample_submission.csv')
submission['meter_reading'] = res
submission.loc[submission['meter_reading']<0, 'meter_reading'] = 0
submission.to_csv('submission_fe_lgbm.csv', index=False)
submission
